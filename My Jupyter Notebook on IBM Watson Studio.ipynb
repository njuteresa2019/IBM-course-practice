# %% [markdown]
# # My Jupyter Notebook on IBM Data Science Experience

# %% [markdown]
# **Yuqiu Wang**
# Desired occupation: Data analyst

# %% [markdown]
# *I am interested in data science because it enables me to speak the languages of what data whisper and communicate between data and people*

# %% [markdown]
# ### Code is cell 5 is a simple calculation on an assigned variable

# %%
x=1
100+x
# Out:
# 101

# %% [markdown]
# **Pet Shopping**
# ![pet%20shopping.jpg](attachment:pet%20shopping.jpg)
#
# ---
# **shopping list**
# 1. Cat toys:
# ⋅⋅* cat dancer.
# ⋅⋅* ripple rug.
# 2. Flea control:
# ⋅⋅* revolution plus.
# 3. Cat food
# ⋅⋅* weight-control.
# ⋅⋅* treats.
#
#
# ***
# **price table**
#
# | product       | carrier       | price |
# | -------------:|:-------------:| -----:|
# | cat dancer    | chewy         |      2|
# | ripple rug    | amazon        |     39|
# | revolution plus| pet hosptial |    120|
#
# ___
#
# > “I used to love dogs until I discovered cats.” – Nafisa Joseph
